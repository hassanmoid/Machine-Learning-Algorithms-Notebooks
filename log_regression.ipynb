# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/sample_data/ex2data1.txt',sep=',',names = ['score1','score2','admission'])
df1 = pd.read_csv('/content/sample_data/ex2data2.txt',sep=',',names = ['score1','score2','admission'])
print(df.shape)
print(df1.shape)
# Out:
# (100, 3)
# (118, 3)

# %%
df.plot(x='score1',y='score2',kind='scatter',c='admission',colormap='BrBG_r')

# %%
df1.plot(x='score1',y='score2',kind='scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
y = df['admission'].values.reshape(-1,1)
y1 = df1['admission'].values.reshape(-1,1)
#df.plot(x='pop',y='profit',kind='scatter')

print(y.shape)
print(y1.shape)
m = y.shape[0]
m1 = y1.shape[0]
X = np.append(np.ones((m,1)),np.array(df.iloc[:,0:2]),axis=1)
X1 = np.append(np.ones((m1,1)),np.array(df1.iloc[:,0:2]),axis=1)
np.unique(y,return_counts=True)
#df1.iloc[:,0:2].head()
X1[0:10]
# Out:
# (100, 1)
# (118, 1)
# array([[ 1.      ,  0.051267,  0.69956 ],
#        [ 1.      , -0.092742,  0.68494 ],
#        [ 1.      , -0.21371 ,  0.69225 ],
#        [ 1.      , -0.375   ,  0.50219 ],
#        [ 1.      , -0.51325 ,  0.46564 ],
#        [ 1.      , -0.52477 ,  0.2098  ],
#        [ 1.      , -0.39804 ,  0.034357],
#        [ 1.      , -0.30588 , -0.19225 ],
#        [ 1.      ,  0.016705, -0.40424 ],
#        [ 1.      ,  0.13191 , -0.51389 ]])

# %%
def sigmoid(x):
  sig = 1/(1+np.exp(np.negative(x)))
  return sig
  
a = [1,20,300,0]
sigmoid(a)
# Out:
# array([0.73105858, 1.        , 1.        , 0.5       ])

# %%
def costFunction(theta,X,y):
  """
    Takes in np array theta, X(independent variables) and y(dependent variables) and return the logistic regression cost function and gradient
    """
  m = len(y)
  predictions = sigmoid(np.dot(X,theta))
  error = (np.multiply(-y,np.log(predictions))) - (np.multiply((1-y),np.log(1-predictions)))
  cost = 1/m * sum(error)
  grad = 1/m * np.dot(X.transpose(),(predictions - y))
  
  return cost,grad

# %%
#n is number of features and m is number of observations/data-points
m , n = X.shape[0],X.shape[1]
#print(m,n)
X = np.append(np.ones((m,1)),np.array(df.iloc[:,0:2]),axis=1)
y = df['admission'].values.reshape(-1,1)
initial_theta = np.zeros((n,1))
cost, grad= costFunction(initial_theta,X,y)
print("Cost of initial theta is",cost)
print("Gradient at initial theta (zeros):",grad)
# Out:
# Cost of initial theta is [0.69314718]
# Gradient at initial theta (zeros): [[ -0.1       ]
#  [-12.00921659]
#  [-11.26284221]]

# %%
# Out:
# (2,)
